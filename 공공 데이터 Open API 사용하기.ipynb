# %%
import requests

# %%
url = 'https://news.v.daum.net/v/20200718135145946'

# %% [markdown]
# ### Get 요청
#
# 1. http get 요청
# 2. query parameter 이용하여 데이터 전달

# %%
resp=requests.get(url)
resp #200 연결에 문제없다는 뜻
# Out:
# <Response [200]>

# %%
resp.text
# Out:
# '<!doctype html>\n<html lang="ko">\n <head data-cloud-area="head"> \n  <meta charset="utf-8"> \n  <meta http-equiv="X-UA-Compatible" content="IE=edge"> \n  <style>\n             @import url(\'//t1.daumcdn.net/harmony_static/cloud/page/2603111efaebe3b9879c7b3c1417b82fff251095.css\');\n            @import url(\'//t1.daumcdn.net/harmony_static/cloud/2020/07/17/components.3d862fe71408d5a2b5ee.css\')\n        </style> \n  <meta name="robots" content="noindex"> \n  <meta property="mccp:docId" content="AOm4KYiSNo"> \n  <meta property="og:site_name" content="다음 뉴스" data-cloud="pc_html_head_meta"> \n  <meta property="og:title" content="트럼프 &quot;난 마스크 신봉자..의무화는 안해&quot;" data-cloud="pc_html_head_meta"> \n  <meta property="og:regDate" content="20200718135145" data-cloud="pc_html_head_meta"> \n  <meta property="og:description" content="[서울=뉴시스] 김예진 기자 = 미국에서 신종 코로나바이러스 감염증(코로나19)의 하루 신규 확진자가 연일 7만 명을 넘고 있는 가운데 도널드 트럼프 미국 대통령이 마스크를 의무적으로 착용하도록 하는 국가 권한을 발동하지 않겠다고 밝혔다. 더힐 등에 따르면 트럼프 대통령은 17일(현지시간
# ...

# %% [markdown]
# ### Post 요청
#
# 1. http post 요청하기
# 2. post data 이용하여 데이터 전달하기

# %%
url ='https://nid.naver.com/nidlogin.login?mode=form&url=https%3A%2F%2Fwww.naver.com'

data={
    'id': 'hanazzang99'
    ,'pwd': '*******' # 실제 비밀번호 넣으면 됨 
} 
resp = requests.post(url,data=data)
resp.text
# Out:
# '<!DOCTYPE html>\n<html lang="ko">\n<head>\n\t<meta charset="UTF-8">\n\t<meta http-equiv="X-UA-Compatible" content="IE=edge">\n\t<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no">\n\t<title>네이버 : 로그인</title>\n\t<link rel="stylesheet" type="text/css" href="https://nid.naver.com/login/css/global/desktop/w_20200707.css">\n</head>\n<body class="">\n<div class="theme_txt" id="theme_txt_message">\n\t<p><strong>안전한 네이버 로그인을 위해 주소창의 URL과 자물쇠 마크를 확인하세요!</strong></p>\n</div>\n<div id="wrap">\n    <div id="u_skip">\n        <a href="#content" id="u_skip_anchor"><span>본문으로 바로가기</span></a>\n    </div>\n\t<!-- header -->\n\t<div id="header">\n\t\t<h1><a href="https://www.naver.com" class="sp h_logo" id="log.naver"><span class="blind">NAVER</span></a></h1>\n\t\t<div class="lang">\n\t\t\t<select id="locale_switch" name="locale_switch" title="언어선택" class="sel">\n\t\t\t\t<option value="ko_KR" >한국어</option>\n\t\t\t\t<option val
# ...

# %% [markdown]
# ### Open API 사용하여 데이터 획득하기
#
# 1. 공공데이터 포털 회원가입/로그인 (http://www.data.go.kr/)
# 2. 오픈 API 페이지에서 원하는 데이터에 접속, 사용 신청
# 3. API 활용 문서 다운로드 받아서 사용 방법 확인
# 4. API 테스트 및 개발

# %% [markdown]
# ### 발급 받은 key값 입력

# %% [markdown]
# 오픈 API 사용 신청하면, 사용자마다 고유한 Key 값을 제공해준다.

# %%
key='uNpMWwhT7HkOMhSJjpxXp1CdtfCQc3M2srjXLjMjw8iKyKNiBttik0v%2Fz%2BUDoXhoNmnQzb52ArlYpAvoU%2FH4sw%3D%3D'

# %% [markdown]
# ### endpoint 확인
# - 오픈API 서비스되는 서버의 ip 혹은 domain 주소
# - api활용 문서 확인해보면 endpoint 확인할 수 있는 코드 들어있으므로 복사해서 사용한다.
# - datatype: xml 혹은 json 설정하여 받아오는데 최근에는 json 형식 많이 사용
# - serviceKey에 위에 발급받은 key값 할당해준다.

# %%
endpoint=f"http://apis.data.go.kr/1360000/VilageFcstInfoService/getVilageFcst?serviceKey={my_key}&numOfRows=10&pageNo=1&base_date=20151021&base_time=0230&nx=55&ny=127&dataType=JSON"

# %%
print(endpoint)
# Out:
# http://apis.data.go.kr/1360000/VilageFcstInfoService/getVilageFcst?serviceKey=uNpMWwhT7HkOMhSJjpxXp1CdtfCQc3M2srjXLjMjw8iKyKNiBttik0v%2Fz%2BUDoXhoNmnQzb52ArlYpAvoU%2FH4sw%3D%3D&numOfRows=10&pageNo=1&base_date=20151021&base_time=0230&nx=55&ny=127&dataType=JSON

# %%
#api 호출
resp=requests.get(endpoint)
print(resp.status_code)
print(resp.text)
# Out:
# 200
# {"response":{"header":{"resultCode":"10","resultMsg":"최근 1일 간의 자료만 제공합니다."}}}

# %%
data=resp.json()

# %%
data
# Out:
# {'response': {'header': {'resultCode': '10',
#    'resultMsg': '최근 1일 간의 자료만 제공합니다.'}}}

# %% [markdown]
# json 형식으로 불러오면 python dict 형식으로 받아서 가공하여 사용 가능
